# %%
import math
import pandas as pd

def shannon_entropy(series):
    probs = series.value_counts(normalize=True)
    return -(probs * probs.apply(lambda p: math.log2(p))).sum()

# Load Titanic dataset
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

print("Available columns:", df.columns.tolist())
col = input("Enter column name: ")

if col in df.columns:
    print(f"Shannon Entropy of '{col}': {shannon_entropy(df[col])}")
else:
    print("Column not found. Try again.")
# Out:
# Available columns: ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
# Enter column name: Name
# Shannon Entropy of 'Name': 9.79928162152192
