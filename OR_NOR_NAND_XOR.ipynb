# %%
import numpy as np

def step_func(x):
    return 1 if x>=0 else 0

def perceptron_learning(z,y,learning_rate=0.1,epochs=10):
    wei=np.zeros(z.shape[1])
    bias=0
    for epoch in range(epochs):
        for i in range(len(z)):
            lin_op=np.dot(z[i],wei)+bias
            pred=step_func(lin_op)
            error=y[i]-pred
            wei+=learning_rate*error*z[i]
            bias+=learning_rate*error
    return wei,bias
z=np.array([[0,0],[0,1],[1,0],[1,1]])
y=np.array([0,1,1,1])
wei,bias=perceptron_learning(z,y)
    
def predict(z,wei,bias):
    lin_op=np.dot(z,wei)+bias
    return step_func(lin_op)
    
for x in z:
    print(f"Input: {x}, Predicted  Output: {predict(x,wei,bias)}")
# Out:
# Input: [0 0], Predicted  Output: 0
# Input: [0 1], Predicted  Output: 1
# Input: [1 0], Predicted  Output: 1
# Input: [1 1], Predicted  Output: 1

# %%
import numpy as np

def step_func(x):
    return 1 if x>=0 else 0

def perceptron_learning(z,y,learning_rate=0.1,epochs=10):
    wei=np.zeros(z.shape[1])
    bias=0
    for epoch in range(epochs):
        for i in range(len(z)):
            lin_op=np.dot(z[i],wei)+bias
            pred=step_func(lin_op)
            error=y[i]-pred
            wei+=learning_rate*error*z[i]
            bias+=learning_rate*error
    return wei,bias
z=np.array([[0,0],[0,1],[1,0],[1,1]])
y=np.array([0,1,1,0])
wei,bias=perceptron_learning(z,y)
    
def predict(z,wei,bias):
    lin_op=np.dot(z,wei)+bias
    return step_func(lin_op)
    
for x in z:
    print(f"Input: {x}, Predicted  Output: {predict(x,wei,bias)}")
# Out:
# Input: [0 0], Predicted  Output: 1
# Input: [0 1], Predicted  Output: 1
# Input: [1 0], Predicted  Output: 0
# Input: [1 1], Predicted  Output: 0

# %%
import numpy as np

def step_func(x):
    return 1 if x>=0 else 0

def perceptron_learning(z,y,learning_rate=0.1,epochs=10):
    wei=np.zeros(z.shape[1])
    bias=0
    for epoch in range(epochs):
        for i in range(len(z)):
            lin_op=np.dot(z[i],wei)+bias
            pred=step_func(lin_op)
            error=y[i]-pred
            wei+=learning_rate*error*z[i]
            bias+=learning_rate*error
    return wei,bias
z=np.array([[0,0],[0,1],[1,0],[1,1]])
y=np.array([1,1,1,0])
wei,bias=perceptron_learning(z,y)
    
def predict(z,wei,bias):
    lin_op=np.dot(z,wei)+bias
    return step_func(lin_op)
    
for x in z:
    print(f"Input: {x}, Predicted  Output: {predict(x,wei,bias)}")
# Out:
# Input: [0 0], Predicted  Output: 1
# Input: [0 1], Predicted  Output: 1
# Input: [1 0], Predicted  Output: 1
# Input: [1 1], Predicted  Output: 0

# %%
import numpy as np

def step_func(x):
    return 1 if x>=0 else 0

def perceptron_learning(z,y,learning_rate=0.1,epochs=10):
    wei=np.zeros(z.shape[1])
    bias=0
    for epoch in range(epochs):
        for i in range(len(z)):
            lin_op=np.dot(z[i],wei)+bias
            pred=step_func(lin_op)
            error=y[i]-pred
            wei+=learning_rate*error*z[i]
            bias+=learning_rate*error
    return wei,bias
z=np.array([[0,0],[0,1],[1,0],[1,1]])
y=np.array([0,0,0,1])
wei,bias=perceptron_learning(z,y)
    
def predict(z,wei,bias):
    lin_op=np.dot(z,wei)+bias
    return step_func(lin_op)
    
for x in z:
    print(f"Input: {x}, Predicted  Output: {predict(x,wei,bias)}")
# Out:
# Input: [0 0], Predicted  Output: 0
# Input: [0 1], Predicted  Output: 0
# Input: [1 0], Predicted  Output: 0
# Input: [1 1], Predicted  Output: 1

# %%
import numpy as np

# Sigmoid activation
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# Derivative of sigmoid
def sigmoid_derivative(x):
    return x * (1 - x)

# Training data for XOR
X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[0],[1],[1],[0]])

# Initialize weights and biases
np.random.seed(42)
input_layer_neurons = 2
hidden_layer_neurons = 2
output_neurons = 1

# Random weights
wh = np.random.uniform(size=(input_layer_neurons, hidden_layer_neurons))
bh = np.random.uniform(size=(1, hidden_layer_neurons))
wo = np.random.uniform(size=(hidden_layer_neurons, output_neurons))
bo = np.random.uniform(size=(1, output_neurons))

# Training
lr = 0.1
epochs = 10000

for epoch in range(epochs):
    # Forward pass
    hidden_input = np.dot(X, wh) + bh
    hidden_output = sigmoid(hidden_input)

    final_input = np.dot(hidden_output, wo) + bo
    final_output = sigmoid(final_input)

    # Backpropagation
    error = y - final_output
    d_output = error * sigmoid_derivative(final_output)

    error_hidden = d_output.dot(wo.T)
    d_hidden = error_hidden * sigmoid_derivative(hidden_output)

    # Update weights
    wo += hidden_output.T.dot(d_output) * lr
    bo += np.sum(d_output, axis=0, keepdims=True) * lr
    wh += X.T.dot(d_hidden) * lr
    bh += np.sum(d_hidden, axis=0, keepdims=True) * lr

# Testing
print("Final outputs after training:")
for i in range(len(X)):
    print(f"Input: {X[i]} -> Predicted Output: {final_output[i]}")
# Out:
# Final outputs after training:
# Input: [0 0] -> Predicted Output: [0.05322146]
# Input: [0 1] -> Predicted Output: [0.95171535]
# Input: [1 0] -> Predicted Output: [0.95160449]
# Input: [1 1] -> Predicted Output: [0.05175396]
